# %%
# Load environment variables and set up auto-reload
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Research Supervisor
#
# *The supervisor has a simple job: delegate research tasks to an appropriate number of sub-agents.*
#
# Here is our overall research flow:
#
# ![image.webp](attachment:834d54a0-26dc-48fc-bc7f-39713ebf5396.webp)
#
# We previously built a research agent bound to either custom tools or MCP server. Now, what happens if the request is complex and has several sub-topics? Single agent response quality *can* suffer with multiple sub-topics (e.g., compare A to B to C) because a single context window needs to store and reason about tool feedback across all of the sub-topics.
#
# [Numerous failure modes](https://www.dbreunig.com/2025/06/22/how-contexts-fail-and-how-to-fix-them.html), such as [context clash](https://www.dbreunig.com/2025/06/22/how-contexts-fail-and-how-to-fix-them.html), become prevalent as the context window accumulates tool calls across many different sub-topics. As discussed in [Anthropic's blog post](https://www.anthropic.com/engineering/built-multi-agent-research-system), multi-agent systems can split sub-topic to sub-agents with isolated context windows. We'll build a system where a supervisor determines if the research brief can be broken-down into independent sub-topics and delegates to sub-agents with isolated context windows.
#
# ![image.webp](attachment:cac50ae6-f10d-4f40-8604-d4b3244628ed.webp)
#
# ### Prompt
#
# Now, let's design a prompt for the supervisor that follows the principles we've discussed, and include some insights from [the research literature](https://www.anthropic.com/engineering/built-multi-agent-research-system).
#
# #### 1. Think Like The Agent
# What instructions would you give a new work colleague?
# - **Read the question carefully** - What specific information does the user need?
# - **Decide how to delegate the research** - Carefully consider the question and decide how to delegate the research. Are there multiple independent directions that can be explored simultaneously?
# - **After each call to ConductResearch, pause and assess** - Do I have enough to answer? What's still missing?
#
# #### 2. Concrete Heuristics (For task delegation)
# Use **Hard Limits** to prevent the research agent from calling tools excessively:
# - **Bias towards single agent** - Use single agent for simplicity unless the user request has clear opportunity for parallelization.
# - **Stop when you can answer confidently** - Don't keep delegating research for perfection.
# - **Limit tool calls** - Always stop after 3 tool calls to ConductResearch if you cannot find the right source(s).
#
# #### 3. Show your thinking
# Before you call ConductResearch tool call, use think_tool to plan your approach:
# - Can the task be broken down into smaller sub-tasks?
#
# After each ConductResearch tool call, use think_tool to analyze the results:
# - What key information did I find?
# - What's missing?
# - Do I have enough to answer the question comprehensively?
# - Should I search more or provide my answer?
#
# #### 4. Scaling rules
# Simple fact-finding, lists, and rankings can use a single sub-agent.
# - *Example*: List the top 10 coffee shops in San Francisco -> Use 1 sub-agent
#
# Comparisons presented in the user request can use a sub-agent for each element of the comparison.
# - *Example*: Compare OpenAI vs. Anthropic vs. DeepMind approaches to AI safety -> Use 3 sub-agents.
# - Delegate clear, distinct, non-overlapping subtopics

# %%
from utils import show_prompt
from deep_research_from_scratch.prompts import lead_researcher_prompt
show_prompt(lead_researcher_prompt, "Lead Researcher Prompt")
# Out:
# ╭──────────────────────────────────────────── Lead Researcher Prompt ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  You are a research supervisor. Your job is to conduct research by calling the "ConductResearch" tool. For      │
# │  context, today's date is {date}.                                                                               │
# │                                                                                                                 │
# │  <Task>                                                                                                         │
# │  Your focus is to call the "ConductResearch" tool to conduct research against the overall research question     │
# │  passed in by the user.                                                                                         │
# │  When you are completely satisfied with the research findings returned from the tool calls, then you should     │
# │  call the "ResearchComplete" tool to indicate that you are done with your research.                             │
# │  </Task>                                                                                                        │
# │                                                                                                                 │
# │  <Available Tools>                                                                                              │
# │  You have access to three main tools:                                                                           │
# │  1. **ConductResearch**: Delegate research tasks to specialized sub-agents                                      │
# │  2. **ResearchComplete**: Indicate that research is complete                                                    │
# │  3. **think_tool**: For reflection and strategic planning during research                                       │
# │                                                                                                                 │
# │  **CRITICAL: Use think_tool before calling ConductResearch to plan your approach, and after each                │
# │  ConductResearch to assess progress**                                                                           │
# │  **PARALLEL RESEARCH**: When you identify multiple independent sub-topics that can be explored simultaneously,  │
# │  make multiple ConductResearch tool calls in a single response to enable parallel research execution. This is   │
# │  more efficient than sequential research for comparative or multi-faceted questions. Use at most                │
# │  {max_concurrent_research_units} parallel agents per iteration.                                                 │
# │  </Available Tools>                                                                                             │
# │                                                                                                                 │
# │  <Instructions>                                                                                                 │
# │  Think like a research manager with limited time and resources. Follow these steps:                             │
# │                                                                                                                 │
# │  1. **Read the question carefully** - What specific information does the user need?                             │
# │  2. **Decide how to delegate the research** - Carefully consider the question and decide how to delegate the    │
# │  research. Are there multiple independent directions that can be explored simultaneously?                       │
# │  3. **After each call to ConductResearch, pause and assess** - Do I have enough to answer? What's still         │
# │  missing?                                                                                                       │
# │  </Instructions>                                                                                                │
# │                                                                                                                 │
# │  <Hard Limits>                                                                                                  │
# │  **Task Delegation Budgets** (Prevent excessive delegation):                                                    │
# │  - **Bias towards single agent** - Use single agent for simplicity unless the user request has clear            │
# │  opportunity for parallelization                                                                                │
# │  - **Stop when you can answer confidently** - Don't keep delegating research for perfection                     │
# │  - **Limit tool calls** - Always stop after {max_researcher_iterations} tool calls to think_tool and            │
# │  ConductResearch if you cannot find the right sources                                                           │
# │  </Hard Limits>                                                                                                 │
# │                                                                                                                 │
# │  <Show Your Thinking>                                                                                           │
# │  Before you call ConductResearch tool call, use think_tool to plan your approach:                               │
# │  - Can the task be broken down into smaller sub-tasks?                                                          │
# │                                                                                                                 │
# │  After each ConductResearch tool call, use think_tool to analyze the results:                                   │
# │  - What key information did I find?                                                                             │
# │  - What's missing?                                                                                              │
# │  - Do I have enough to answer the question comprehensively?                                                     │
# │  - Should I delegate more research or call ResearchComplete?                                                    │
# │  </Show Your Thinking>                                                                                          │
# │                                                                                                                 │
# │  <Scaling Rules>                                                                                                │
# │  **Simple fact-finding, lists, and rankings** can use a single sub-agent:                                       │
# │  - *Example*: List the top 10 coffee shops in San Francisco → Use 1 sub-agent                                   │
# │                                                                                                                 │
# │  **Comparisons presented in the user request** can use a sub-agent for each element of the comparison:          │
# │  - *Example*: Compare OpenAI vs. Anthropic vs. DeepMind approaches to AI safety → Use 3 sub-agents              │
# │  - Delegate clear, distinct, non-overlapping subtopics                                                          │
# │                                                                                                                 │
# │  **Important Reminders:**                                                                                       │
# │  - Each ConductResearch call spawns a dedicated research agent for that specific topic                          │
# │  - A separate agent will write the final report - you just need to gather information                           │
# │  - When calling ConductResearch, provide complete standalone instructions - sub-agents can't see other agents'  │
# │  work                                                                                                           │
# │  - Do NOT use acronyms or abbreviations in your research questions, be very clear and specific                  │
# │  </Scaling Rules>                                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### State
#
# The supervisor state manages the overall research coordination, while the researcher state handles individual research tasks.

# %%
# %%writefile ../src/deep_research_from_scratch/state_multi_agent_supervisor.py

"""
State Definitions for Multi-Agent Research Supervisor

This module defines the state objects and tools used for the multi-agent
research supervisor workflow, including coordination state and research tools.
"""

import operator
from typing_extensions import Annotated, TypedDict, Sequence

from langchain_core.messages import BaseMessage
from langchain_core.tools import tool
from langgraph.graph.message import add_messages
from pydantic import BaseModel, Field

class SupervisorState(TypedDict):
    """
    State for the multi-agent research supervisor.
    
    Manages coordination between supervisor and research agents, tracking
    research progress and accumulating findings from multiple sub-agents.
    """
    
    # Messages exchanged with supervisor for coordination and decision-making
    supervisor_messages: Annotated[Sequence[BaseMessage], add_messages]
    # Detailed research brief that guides the overall research direction
    research_brief: str
    # Processed and structured notes ready for final report generation
    notes: Annotated[list[str], operator.add] = []
    # Counter tracking the number of research iterations performed
    research_iterations: int = 0
    # Raw unprocessed research notes collected from sub-agent research
    raw_notes: Annotated[list[str], operator.add] = []

@tool
class ConductResearch(BaseModel):
    """Tool for delegating a research task to a specialized sub-agent."""
    research_topic: str = Field(
        description="The topic to research. Should be a single topic, and should be described in high detail (at least a paragraph).",
    )

@tool
class ResearchComplete(BaseModel):
    """Tool for indicating that the research process is complete."""
    pass
# Out:
# Overwriting ../src/deep_research_from_scratch/state_multi_agent_supervisor.py

# %% [markdown]
# ### Multi-agent
#
# Now, we'll define our agent. A multi-agent system is a system that consists of multiple agents that work together to complete a task. The main benefit is context isolated, as discussed in [Context Engineering for Agents](https://blog.langchain.com/context-engineering-for-agents/).

# %%
# %%writefile ../src/deep_research_from_scratch/multi_agent_supervisor.py

"""Multi-agent supervisor for coordinating research across multiple specialized agents.

This module implements a supervisor pattern where:
1. A supervisor agent coordinates research activities and delegates tasks
2. Multiple researcher agents work on specific sub-topics independently
3. Results are aggregated and compressed for final reporting

The supervisor uses parallel research execution to improve efficiency while
maintaining isolated context windows for each research topic.
"""

import asyncio

from typing_extensions import Literal

from langchain.chat_models import init_chat_model
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import (
    HumanMessage, 
    BaseMessage, 
    SystemMessage, 
    ToolMessage,
    filter_messages
)
from langgraph.graph import StateGraph, START, END
from langgraph.types import Command

from deep_research_from_scratch.prompts import lead_researcher_prompt
from deep_research_from_scratch.research_agent import researcher_agent
from deep_research_from_scratch.state_multi_agent_supervisor import (
    SupervisorState, 
    ConductResearch, 
    ResearchComplete
)
from deep_research_from_scratch.utils import get_today_str, think_tool

def get_notes_from_tool_calls(messages: list[BaseMessage]) -> list[str]:
    """Extract research notes from ToolMessage objects in supervisor message history.
    
    This function retrieves the compressed research findings that sub-agents
    return as ToolMessage content. When the supervisor delegates research to
    sub-agents via ConductResearch tool calls, each sub-agent returns its
    compressed findings as the content of a ToolMessage. This function
    extracts all such ToolMessage content to compile the final research notes.
    
    Args:
        messages: List of messages from supervisor's conversation history
        
    Returns:
        List of research note strings extracted from ToolMessage objects
    """
    return [tool_msg.content for tool_msg in filter_messages(messages, include_types="tool")]

# Ensure async compatibility for Jupyter environments
try:
    import nest_asyncio
    # Only apply if running in Jupyter/IPython environment
    try:
        from IPython import get_ipython
        if get_ipython() is not None:
            nest_asyncio.apply()
    except ImportError:
        pass  # Not in Jupyter, no need for nest_asyncio
except ImportError:
    pass  # nest_asyncio not available, proceed without it


# ===== CONFIGURATION =====

supervisor_tools = [ConductResearch, ResearchComplete, think_tool]
supervisor_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
supervisor_model_with_tools = supervisor_model.bind_tools(supervisor_tools)

# System constants
# Maximum number of tool call iterations for individual researcher agents
# This prevents infinite loops and controls research depth per topic
max_researcher_iterations = 6 # Calls to think_tool + ConductResearch

# Maximum number of concurrent research agents the supervisor can launch
# This is passed to the lead_researcher_prompt to limit parallel research tasks
max_concurrent_researchers = 3

# ===== SUPERVISOR NODES =====

async def supervisor(state: SupervisorState) -> Command[Literal["supervisor_tools"]]:
    """Coordinate research activities.
    
    Analyzes the research brief and current progress to decide:
    - What research topics need investigation
    - Whether to conduct parallel research
    - When research is complete
    
    Args:
        state: Current supervisor state with messages and research progress
        
    Returns:
        Command to proceed to supervisor_tools node with updated state
    """
    supervisor_messages = state.get("supervisor_messages", [])
    
    # Prepare system message with current date and constraints
    system_message = lead_researcher_prompt.format(
        date=get_today_str(), 
        max_concurrent_research_units=max_concurrent_researchers,
        max_researcher_iterations=max_researcher_iterations
    )
    messages = [SystemMessage(content=system_message)] + supervisor_messages
    
    # Make decision about next research steps
    response = await supervisor_model_with_tools.ainvoke(messages)
    
    return Command(
        goto="supervisor_tools",
        update={
            "supervisor_messages": [response],
            "research_iterations": state.get("research_iterations", 0) + 1
        }
    )

async def supervisor_tools(state: SupervisorState) -> Command[Literal["supervisor", "__end__"]]:
    """Execute supervisor decisions - either conduct research or end the process.
    
    Handles:
    - Executing think_tool calls for strategic reflection
    - Launching parallel research agents for different topics
    - Aggregating research results
    - Determining when research is complete
    
    Args:
        state: Current supervisor state with messages and iteration count
        
    Returns:
        Command to continue supervision, end process, or handle errors
    """
    supervisor_messages = state.get("supervisor_messages", [])
    research_iterations = state.get("research_iterations", 0)
    most_recent_message = supervisor_messages[-1]
    
    # Initialize variables for single return pattern
    tool_messages = []
    all_raw_notes = []
    next_step = "supervisor"  # Default next step
    should_end = False
    
    # Check exit criteria first
    exceeded_iterations = research_iterations >= max_researcher_iterations
    no_tool_calls = not most_recent_message.tool_calls
    research_complete = any(
        tool_call["name"] == "ResearchComplete" 
        for tool_call in most_recent_message.tool_calls
    )
    
    if exceeded_iterations or no_tool_calls or research_complete:
        should_end = True
        next_step = END
    
    else:
        # Execute ALL tool calls before deciding next step
        try:
            # Separate think_tool calls from ConductResearch calls
            think_tool_calls = [
                tool_call for tool_call in most_recent_message.tool_calls 
                if tool_call["name"] == "think_tool"
            ]
            
            conduct_research_calls = [
                tool_call for tool_call in most_recent_message.tool_calls 
                if tool_call["name"] == "ConductResearch"
            ]

            # Handle think_tool calls (synchronous)
            for tool_call in think_tool_calls:
                observation = think_tool.invoke(tool_call["args"])
                tool_messages.append(
                    ToolMessage(
                        content=observation,
                        name=tool_call["name"],
                        tool_call_id=tool_call["id"]
                    )
                )

            # Handle ConductResearch calls (asynchronous)
            if conduct_research_calls:
                # Launch parallel research agents
                coros = [
                    researcher_agent.ainvoke({
                        "researcher_messages": [
                            HumanMessage(content=tool_call["args"]["research_topic"])
                        ],
                        "research_topic": tool_call["args"]["research_topic"]
                    }) 
                    for tool_call in conduct_research_calls
                ]

                # Wait for all research to complete
                tool_results = await asyncio.gather(*coros)

                # Format research results as tool messages
                # Each sub-agent returns compressed research findings in result["compressed_research"]
                # We write this compressed research as the content of a ToolMessage, which allows
                # the supervisor to later retrieve these findings via get_notes_from_tool_calls()
                research_tool_messages = [
                    ToolMessage(
                        content=result.get("compressed_research", "Error synthesizing research report"),
                        name=tool_call["name"],
                        tool_call_id=tool_call["id"]
                    ) for result, tool_call in zip(tool_results, conduct_research_calls)
                ]
                
                tool_messages.extend(research_tool_messages)

                # Aggregate raw notes from all research
                all_raw_notes = [
                    "\n".join(result.get("raw_notes", [])) 
                    for result in tool_results
                ]
                
        except Exception as e:
            print(f"Error in supervisor tools: {e}")
            should_end = True
            next_step = END
    
    # Single return point with appropriate state updates
    if should_end:
        return Command(
            goto=next_step,
            update={
                "notes": get_notes_from_tool_calls(supervisor_messages),
                "research_brief": state.get("research_brief", "")
            }
        )
    else:
        return Command(
            goto=next_step,
            update={
                "supervisor_messages": tool_messages,
                "raw_notes": all_raw_notes
            }
        )

# ===== GRAPH CONSTRUCTION =====

# Build supervisor graph
supervisor_builder = StateGraph(SupervisorState)
supervisor_builder.add_node("supervisor", supervisor)
supervisor_builder.add_node("supervisor_tools", supervisor_tools)
supervisor_builder.add_edge(START, "supervisor")
supervisor_agent = supervisor_builder.compile()
# Out:
# Overwriting ../src/deep_research_from_scratch/multi_agent_supervisor.py

# %%
from IPython.display import Image, display
from deep_research_from_scratch.multi_agent_supervisor import supervisor_agent

# Show the agent
display(Image(supervisor_agent.get_graph(xray=True).draw_mermaid_png()))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761829805.626549  906049 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1761829805.633653  906049 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1761829805.636365  906049 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1761829805.637159  906049 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# E0000 00:00:1761829805.646202  906049 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
# Run the multi-agent supervisor agent
from utils import format_messages
from langchain_core.messages import HumanMessage

research_brief = """I want to identify and evaluate the coffee shops in San Francisco that are considered the best based specifically  
on coffee quality. My research should focus on analyzing and comparing coffee shops within the San Francisco area, 
using coffee quality as the primary criterion. I am open regarding methods of assessing coffee quality (e.g.,      
expert reviews, customer ratings, specialty coffee certifications), and there are no constraints on ambiance,      
location, wifi, or food options unless they directly impact perceived coffee quality. Please prioritize primary    
sources such as the official websites of coffee shops, reputable third-party coffee review organizations (like     
Coffee Review or Specialty Coffee Association), and prominent review aggregators like Google or Yelp where direct  
customer feedback about coffee quality can be found. The study should result in a well-supported list or ranking of
the top coffee shops in San Francisco, emphasizing their coffee quality according to the latest available data as  
of July 2025."""

result = await supervisor_agent.ainvoke({"supervisor_messages": [HumanMessage(content=f"{research_brief}.")]})
format_messages(result['supervisor_messages'])
# Out:
# E0000 00:00:1761829905.017526  906049 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ I want to identify and evaluate the coffee shops in San Francisco that are considered the best based            │
# │ specifically                                                                                                    │
# │ on coffee quality. My research should focus on analyzing and comparing coffee shops within the San Francisco    │
# │ area,                                                                                                           │
# │ using coffee quality as the primary criterion. I am open regarding methods of assessing coffee quality (e.g.,   │
# │ expert reviews, customer ratings, specialty coffee certifications), and there are no constraints on ambiance,   │
# │ location, wifi, or food options unless they directly impact perceived coffee quality. Please prioritize primary │
# │ sources such as the official websites of coffee shops, reputable third-party coffee review organizations (like  │
# │ Coffee Review or Specialty Coffee Association), and prominent review aggregators like Google or Yelp where      │
# │ direct                                                                                                          │
# │ customer feedback about coffee quality can be found. The study should result in a well-supported list or        │
# │ ranking of                                                                                                      │
# │ the top coffee shops in San Francisco, emphasizing their coffee quality according to the latest available data  │
# │ as                                                                                                              │
# │ of July 2025..                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: think_tool                                                                                        │
# │    Args: {                                                                                                      │
# │   "reflection": "The user wants a list/ranking of the best coffee shops in San Francisco based on coffee        │
# │ quality. I need to delegate this research to a sub-agent. The sub-agent should focus on specific sources:       │
# │ official websites, reputable coffee review organizations, and prominent review aggregators (Google, Yelp),      │
# │ prioritizing feedback related to coffee quality. I will formulate a comprehensive research topic for the        │
# │ sub-agent."                                                                                                     │
# │ }                                                                                                               │
# │    ID: fd9f24a7-72ed-41ee-a229-5bf5d0f6a7f2                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Reflection recorded: The user wants a list/ranking of the best coffee shops in San Francisco based on coffee    │
# │ quality. I need to delegate this research to a sub-agent. The sub-agent should focus on specific sources:       │
# │ official websites, reputable coffee review organizations, and prominent review aggregators (Google, Yelp),      │
# │ prioritizing feedback related to coffee quality. I will formulate a comprehensive research topic for the        │
# │ sub-agent.                                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ConductResearch                                                                                   │
# │    Args: {                                                                                                      │
# │   "research_topic": "Identify and evaluate the best coffee shops in San Francisco based on coffee quality as of │
# │ July 2025. This evaluation should consider expert reviews, customer ratings from Google and Yelp, and specialty │
# │ coffee certifications. Prioritize information from official coffee shop websites, Coffee Review, and the        │
# │ Specialty Coffee Association. The research should result in a list or ranking emphasizing coffee quality."      │
# │ }                                                                                                               │
# │    ID: 12043d53-fc58-4909-a480-907a3c55cb6c                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ **List of Queries and Tool Calls Made**                                                                         │
# │                                                                                                                 │
# │ 1.  "best coffee shops San Francisco expert reviews customer ratings"                                           │
# │ 2.  "Coffee Review San Francisco coffee shops"                                                                  │
# │ 3.  "Specialty Coffee Association San Francisco coffee shops certifications"                                    │
# │ 4.  "top rated San Francisco coffee shops 2024"                                                                 │
# │ 5.  "The Coffee Movement San Francisco Coffee Review SCA certification customer ratings"                        │
# │ 6.  "Sightglass Coffee San Francisco Coffee Review SCA certification customer ratings"                          │
# │ 7.  "Ritual Coffee Roasters San Francisco Coffee Review SCA certification customer ratings"                     │
# │ 8.  "top-rated San Francisco coffee shops with Google reviews"                                                  │
# │ 9.  "Coffee Review The Coffee Movement San Francisco"                                                           │
# │ 10. "Coffee Review Sightglass Coffee San Francisco"                                                             │
# │ 11. "Sightglass Coffee San Francisco SCA certification"                                                         │
# │ 12. "Coffee Review Ritual Coffee Roasters San Francisco"                                                        │
# │ 13. "Ritual Coffee Roasters San Francisco SCA certification"                                                    │
# │ 14. "Coffee Review Saint Frank Coffee San Francisco"                                                            │
# │ 15. "Saint Frank Coffee San Francisco SCA certification"                                                        │
# │ 16. "Coffee Review Andytown Coffee Roasters San Francisco"                                                      │
# │ 17. "Andytown Coffee Roasters San Francisco SCA certification"                                                  │
# │                                                                                                                 │
# │ **Fully Comprehensive Findings**                                                                                │
# │                                                                                                                 │
# │ San Francisco is a city renowned for its rich coffee culture, offering a diverse array of unique coffee shops   │
# │ that cater to every taste [1]. The city has historically been a significant hub in the development of coffee    │
# │ culture, serving as the birthplace of Wrecking Ball Coffee, where Trish Rothgeb introduced the "waves of        │
# │ coffee" terminology. It's also where Yemeni coffee was introduced to the West Coast by establishments like Port │
# │ of Mokha and Delah Coffee House, where Irish Coffee originated, where many claim Italian espresso culture first │
# │ arrived in the United States, and where vacuum-sealed coffee was invented [6].                                  │
# │                                                                                                                 │
# │ **Specialty Coffee Association (SCA) and Certifications**                                                       │
# │                                                                                                                 │
# │ The Specialty Coffee Association (SCA) Education programs establish the global benchmark for excellence in      │
# │ coffee education [12, 14, 25]. Annually, nearly 80,000 learners in 89 countries choose SCA Education to advance │
# │ their coffee careers, with courses available in almost 40 languages [12, 25]. These programs are developed with │
# │ expert input and incorporate the latest coffee industry research to keep participants at the forefront of the   │
# │ field [12, 25]. The SCA offers globally recognized certificates designed to further coffee careers at all       │
# │ levels [14, 25].                                                                                                │
# │                                                                                                                 │
# │ The SCA Skills Diploma program provides four specialized pathways: Café, Roastery, Coffee Trade, and            │
# │ Sustainable Coffee [13]. To achieve a diploma, individuals must plan their educational path, complete the       │
# │ necessary certificates, and then apply through their SCA learner portal [13]. These certificates serve as       │
# │ foundational building blocks for the industry-recognized SCA Skills Diplomas [14]. SCA courses are delivered    │
# │ globally by hundreds of Authorized SCA Trainers (ASTs) [29]. The SCA's U.S. office is located in Irvine,        │
# │ California [14].                                                                                                │
# │                                                                                                                 │
# │ **Evaluated Coffee Shops in San Francisco Emphasizing Coffee Quality (as of October 2025, based on research     │
# │ conducted in May 2024)**                                                                                        │
# │                                                                                                                 │
# │ The following coffee shops are highly regarded for their coffee quality, based on expert reviews, customer      │
# │ ratings from platforms like Google and Yelp, and indicators of adherence to specialty coffee standards.         │
# │                                                                                                                 │
# │ **1. Sightglass Coffee**                                                                                        │
# │ *   **Expert Reviews & Quality Indicators:** Sightglass Coffee is consistently highlighted in "best of" lists   │
# │ as one of San Francisco's prominent coffee roasters [2, 4, 11, 18, 22]. Its headquarters features a stunning    │
# │ roastery, offering visitors a chance to observe the coffee-making process up close [18]. The company is praised │
# │ for its commitment to quality, including direct relationships with coffee farmers [18, 23]. Their signature     │
# │ espresso blend, "Owl's Howl," is described with tasting notes of dark chocolate, ripe berries, and lemon cake   │
# │ [18]. The Coffeevine review from January 13, 2015, notes that the Owl's Howl blend, made from regularly         │
# │ changing coffees, promises a "deep honey-like body, with notes of ripe berry, chocolate-covered cherry and      │
# │ sweet candied lemon" [23]. Sightglass is recognized for helping to "put San Francisco on the coffee map"        │
# │ through its dedication to quality [18, 23]. Their official website states a commitment to responsible sourcing, │
# │ small-batch roasting, and sustainability, and proudly offers USDA-certified organic coffee [26]. They feature   │
# │ single-origin coffees with detailed tasting notes, such as "Autumnal Equinox" (Strawberry, Cocoa Nib, Orange    │
# │ Blossom Honey), "Guatemala Cubito" (Dried Apricot, Orange Blossom, Milk Chocolate), and "Mexico Finca Santa     │
# │ Cruz" (Loquat, Sierra Fig, Honeydew) [26, 27]. Sightglass Coffee also offers barista classes [27].              │
# │ *   **Customer Ratings:** Sightglass Coffee is highly rated, appearing as #2 on Yelp's "best coffee" search     │
# │ with over 2.2k reviews [2, 11]. On Tripadvisor, it holds a 4.5 out of 5 rating based on 174 unbiased reviews    │
# │ [18]. A Yelp listing for their 301 Divisadero St location shows a 3.9-star rating based on 205 reviews, with    │
# │ popular drink options including the Vanilla Paste Latte and Brown Butter Miso Caramel Latte [22]. While some    │
# │ customer reviews mention issues with grounds in the cup, inconsistent service, or internal shop temperature,    │
# │ many praise the coffee, ambiance, and specific drinks [22].                                                     │
# │ *   **Locations:** Sightglass has multiple physical cafe locations in San Francisco (SoMa, Mission, Divisadero) │
# │ and Los Angeles (Hollywood) [26]. They are also present at Saturday farmer's markets [18].                      │
# │                                                                                                                 │
# │ **2. Ritual Coffee Roasters**                                                                                   │
# │ *   **Expert Reviews & Quality Indicators:** Ritual Coffee Roasters is frequently listed among the best coffee  │
# │ shops in San Francisco [4, 29]. Condé Nast Traveler describes it as a design-driven coffee shop known for its   │
# │ V60 pour-over coffee [29]. Ritual roasts its own beans and is considered to serve "some of the finest coffee    │
# │ San Francisco has to offer," including cold brew, nitro, lattes, cappuccino, and especially pour-over [29]. A   │
# │ review of their "Day Drinker Seasonal Espresso" found it to be complex and surprising, with notes of milk       │
# │ chocolate, orange, and a "laundering freshness." Recommended brewing parameters for this espresso are 204       │
# │ degrees F, 17 grams in, 32 grams out, and a 26-second extraction. The reviewer noted it's not a typical         │
# │ "workhorse" espresso and is best enjoyed on its own. AeroPress preparation yielded unexpected flavors of        │
# │ toasted marshmallow and sweet orange. The roaster's own tasting notes for this espresso include rum-soaked      │
# │ pears, candied ginger, star anise, and chocolate-covered oranges [29]. Ritual sees itself as a pioneer in       │
# │ appreciating coffee's deliciousness, sourcing beans directly from farmers and roasting them in an "aggressively │
# │ light" way, with the goal of crafting the "very best coffee available anywhere" [30]. They are noted for        │
# │ quality and sustainable sourcing [4].                                                                           │
# │ *   **Customer Ratings:** Ritual Coffee Roasters has a 4.2 out of 5 rating on Tripadvisor based on 22 unbiased  │
# │ reviews [28]. Customers praise the "amazing espresso" and friendly, knowledgeable staff [29]. An airport        │
# │ location (SFO) is noted for quick and delicious Americanos for $6, significantly improving the coffee options   │
# │ previously available in that terminal [28].                                                                     │
# │ *   **Specialty Coffee Certifications:** Ritual Academy, associated with Ritual Coffee Co., offers professional │
# │ coffee training and certifications recognized by the SCA, the Academy of Coffee Excellence (ACoE), and the      │
# │ Coffee Quality Institute [30]. They provide comprehensive education covering bean selection, brewing, and       │
# │ sensory analysis [30]. Upcoming courses include SCA Roasting Level 2 - Intermediate (April 8-10, 2025, starting │
# │ at LE 18,500.00 EGP) and SCA Sensory Skills Level 2 - Intermediate (September 14-16, 2025, starting at LE       │
# │ 16,500.00 EGP) [30]. The Roaster Level 2 course is a 3-day program focusing on scientific and technical         │
# │ roasting elements, quality control, and production roast development [30].                                      │
# │ *   **Locations & Offerings:** Located on Valencia Street in the Mission District [29]. They also serve         │
# │ pastries and organic, vegan donuts from Pepples, available in unique flavors like lemon poppyseed and blueberry │
# │ [29].                                                                                                           │
# │                                                                                                                 │
# │ **3. The Coffee Movement**                                                                                      │
# │ *   **Expert Reviews & Quality Indicators:** The Coffee Movement is highly recommended as a "must-visit spot"   │
# │ in San Francisco due to its delicious coffee and pleasant environment [19]. It is listed among the absolute     │
# │ best San Francisco coffee shops [6] and is recognized for craft coffee in a cozy space [4]. Reviewers have      │
# │ described the espresso as "beyond delicious" [19]. The shop is known for its unique offerings, including        │
# │ seasonal lattes [10] and espresso soft serve [17, 20]. The Mission outpost offers two soft serve flavors, with  │
# │ the espresso soft serve making up for the lack of variety [17, 20]. They also offer a limited daily production  │
# │ of around 100 donuts with two rotating flavors, often including yeast and cake options, with lemon glaze yeast  │
# │ donuts being a highlighted favorite [17]. They discourage laptop use to encourage patrons to focus on the       │
# │ coffee and music [17, 20].                                                                                      │
# │ *   **Customer Ratings:** The Coffee Movement receives excellent customer ratings, with a 4.6 out of 5 rating   │
# │ on Tripadvisor based on 19 unbiased reviews [15]. It is ranked #1 on Yelp's "best coffee" search with 708       │
# │ reviews [2].                                                                                                    │
# │ *   **Locations & Offerings:** The Coffee Movement has an original cafe, a Balboa Street location [6, 17], and  │
# │ a Richmond location [10]. Its Mission outpost is located at 2814 19th St, San Francisco, CA 94110, operating    │
# │ inside Side A (a vinyl bar and restaurant) during weekday mornings [17, 21]. The Balboa St location is at 1737  │
# │ Balboa St, San Francisco, CA 94121, open Mon, Tue, Thu 7:00 AM - 2:00 PM and Fri, Sun 7:00 AM - 4:00 PM [16].   │
# │                                                                                                                 │
# │ **4. Saint Frank Coffee**                                                                                       │
# │ *   **Expert Reviews & Quality Indicators:** Saint Frank Coffee is consistently included in guides for the      │
# │ "best coffee shops" in San Francisco [4, 6, 10, 31]. It is known for its "excellent coffee and housemade almond │
# │ macadamia milk" [10, 31]. Reviewers have described the espresso as "beyond delicious" [31]. Eater SF praises    │
# │ Saint Frank as essential to San Francisco coffee culture, stating "when the time is right in the city, nothing  │
# │ else will do" [6]. The coffee shop's focus on quality is further underscored by Jason Yeo, a finalist in the    │
# │ 2024 USBC competition, who works in coffee education and quality assurance at Saint Frank Coffee. Yeo is        │
# │ passionate about the specialty coffee industry, its supply chain, and its ability to connect people, having     │
# │ traveled to coffee origin countries and competed in the United States Barista Championships [32].               │
# │ *   **Customer Ratings:** Saint Frank Coffee receives positive reviews from customers on platforms like The     │
# │ Infatuation and LetsGetLexi [31].                                                                               │
# │ *   **Locations & Offerings:** Saint Frank is located in Russian Hill and also has a Mission location [31]. It  │
# │ features a minimalist setting with a sleek design and offers free Wi-Fi during the week (though without         │
# │ electrical outlets) [10, 31]. Their official website highlights a commitment to coffee and community, and they  │
# │ partner with the 501c3 nonprofit Lift Up for "coffee camp" donations [32].                                      │
# │                                                                                                                 │
# │ **5. Andytown Coffee Roasters**                                                                                 │
# │ *   **Expert Reviews & Quality Indicators:** Andytown Coffee Roasters is a small-batch roaster-retailer that    │
# │ began in 2014, roasting its own coffee and baking pastries nearby [33]. It is frequently mentioned in "best of" │
# │ lists for San Francisco coffee shops [4, 6, 10]. The company emphasizes "meticulous sourcing, small-batch       │
# │ roasting, skilled baristas, and crafting every cup with care and consistency" [34, 35]. They are a certified    │
# │ California Green Business, committed to sustainability through compostable packaging, energy efficiency, and    │
# │ ethical sourcing [34, 35]. Their signature drink is the "Snowy Plover," a refreshing coffee float made with     │
# │ espresso, Pellegrino, and homemade whipped cream [4, 33]. A review of their "Colombia Las Planadas" coffee      │
# │ noted a dominant flavor of chocolate/cocoa powder with a citrusy tang like tangerine on the finish, and was     │
# │ liked best in a French press for its balance [33]. They use a Mahlkonig K30 grinder and a Kees Van Der Westen   │
# │ Spirit coffee machine [33]. Andytown's website provides updates on their sourcing, noting efforts by the        │
# │ Mexican government and security measures that allowed farmers in Bella Vista and Chiapas to better focus on the │
# │ 2025 harvest season [34].                                                                                       │
# │ *   **Customer Ratings:** Andytown Coffee Roasters is highly rated, with an average of 4.8 stars based on 39    │
# │ reviews on Tripadvisor, ranking #20 out of 260 Coffee & Tea spots in San Francisco [33]. Customers consistently │
# │ praise the exquisite flavors, attentive service, friendly staff, and the quality of both coffee and baked goods │
# │ [33].                                                                                                           │
# │ *   **Locations & Offerings:** Andytown has locations including one at 3629 Taraval St and another at 3655      │
# │ Lawton St in the Sunset District [33]. Their Great Highway outpost in Richmond is located steps away from the   │
# │ beach [6, 10]. They offer breakfast and lunch, with notable menu items including the Snowy Plover, scones       │
# │ (particularly chocolate chip pumpkin), cheddar jalapeño corn muffins, and soda bread [33].                      │
# │                                                                                                                 │
# │ **Other Notable Coffee Shops in San Francisco:**                                                                │
# │                                                                                                                 │
# │ Several other coffee shops are frequently mentioned in various "best of" lists, indicating their popularity and │
# │ perceived quality:                                                                                              │
# │ *   **Blue Bottle Coffee:** Known for its focus on single-origin beans and considered a knowledgeable and       │
# │ skillful roaster in the third wave coffee movement [4].                                                         │
# │ *   **Cafe Réveille:** Noted for brunch and outdoor seating [4].                                                │
# │ *   **Caffe Trieste:** A San Francisco institution in North Beach, recognized as the first espresso-based       │
# │ coffee shop on the West Coast, and a historical haunt for figures like Francis Ford Coppola [6, 10].            │
# │ *   **Compton’s Coffee House:** Located in Lower Pacific Heights, known for velvety espresso and housemade      │
# │ seasonal syrups [10].                                                                                           │
# │ *   **Delah Coffee House:** A late-night Yemeni coffee spot in SoMa, offering spiced Yemeni lattes and pastries │
# │ [6, 10].                                                                                                        │
# │ *   **Excelsior Coffee:** A family-run shop in the Excelsior neighborhood with standout espresso drinks and ube │
# │ brownies [10].                                                                                                  │
# │ *   **Flywheel Coffee Roasters:** Praised for handcrafted methods [4] and included in lists of best coffee      │
# │ shops [6].                                                                                                      │
# │ *   **Four Barrel Coffee:** An independent, locally owned roastery in The Mission, known for in-house roasting  │
# │ and smooth espresso. They source beans from third-generation farmers and mill-workers in Latin America,         │
# │ Indonesia, and East Africa [4].                                                                                 │
# │ *   **Grand Coffee:** A preeminent coffee roaster in the Mission with an energetic communal atmosphere, having  │
# │ opened a second location a block from its mini cafe [6, 10].                                                    │
# │ *   **Hey Neighbor Cafe:** A Black and brown-owned business in the Excelsior neighborhood, opened in 2019 by    │
# │ Lea Sabado and Andre Higgenbotham, gaining a loyal fanbase [6].                                                 │
# │ *   **Hi NRG:** Operates out of a wine bar in the Richmond, serving pour-over, espresso, and cafe de olla [10]. │
# │ *   **Home Coffee Roasters:** In Chinatown, focuses on creative espresso drinks with unique toppings [10].      │
# │ *   **Kopiku Indonesian Coffee:** In the Marina, specializes in Indonesian coffee and pastries [10].            │
# │ *   **LINEA CAFFE:** Recognized for its eco-friendly approach and smooth espresso [4].                          │
# │ *   **marigold cafe:** Known for its cafe and flower shop concept [4].                                          │
# │ *   **Nirvana Soul Coffee:** In SoMa, serves creative espresso and tea drinks, including an ube latte [10].     │
# │ *   **Paper Son:** Alex Pong's pop-up in Soma offers Asian-inspired coffee drinks and pastries, merging his     │
# │ Asian American heritage with top-tier espresso and pour-over skills [6, 10].                                    │
# │ *   **Philz Coffee:** Known for made-to-order pour overs [4].                                                   │
# │ *   **Pinhole Coffee:** A bright spot in Bernal Heights, serving a smooth flat white [10].                      │
# │ *   **Port of Mokha:** A hitmaker that brought Yemeni coffee to the West Coast [6].                             │
# │ *   **The Scullery:** A small coffee shop with outdoor seating, located on Geary Street [6].                    │
# │ *   **Sextant Coffee Roasters:** Founder Kinani Ahmed works directly with Ethiopian, Kenyan, and Colombian      │
# │ growers, producing high-end but affordable beans [6].                                                           │
# │ *   **Shoji:** A Japanese cafe in SoMa offering tea and coffee service, including matcha and hojicha lattes [6, │
# │ 10].                                                                                                            │
# │ *   **Simple Pleasures Cafe:** A cozy gathering spot in Richmond with hearty cafe staples and espresso drinks   │
# │ [10].                                                                                                           │
# │ *   **Snowbird Coffee:** In Sunset, serves strong cortados and affogatos in a cave-like space [1, 10].          │
# │ *   **SPRO:** Known for its playful and inventive coffee drinks [6].                                            │
# │ *   **Telescope Coffee:** A SoMa coffee shop noted for signature drinks that are difficult to find elsewhere    │
# │ [6].                                                                                                            │
# │ *   **Third Wheel:** A takeout-only spot in Nopa with matcha and housemade syrups [10].                         │
# │ *   **Wrecking Ball Coffee Roasters:** Known for specialty coffee [4] and for its role in introducing "waves of │
# │ coffee" terminology [6].                                                                                        │
# │                                                                                                                 │
# │ ### Sources                                                                                                     │
# │                                                                                                                 │
# │ [1] Honest Coffee Reviews: Discovering San Francisco's Best Cafes.                                              │
# │ https://www.lemon8-app.com/experience/honest-coffee-reviews-san-francisco?region=us                             │
# │ [2] Best Coffee San Francisco, CA - Last Updated October 2025 - Yelp.                                           │
# │ https://m.yelp.com/search?find_desc=best+coffee&find_loc=San+Francisco%2C+CA                                    │
# │ [3] 16 Best Coffee Shops In San Francisco - Tasting Table.                                                      │
# │ https://www.tastingtable.com/1479970/best-coffee-shops-san-francisco/                                           │
# │ [4] BEST COFEE SHOPS IN SAN FRANCISCO - SUGAR & STAMPS.                                                         │
# │ https://www.sugarandstamps.com/blog/best-coffee-shops-in-san-francisco                                          │
# │ [5] 16 Best Coffee Shops In San Francisco - Tasting Table.                                                      │
# │ https://www.tastingtable.com/1479970/best-coffee-shops-san-francisco/                                           │
# │ [6] The Absolute Best San Francisco Coffee Shops - Eater SF.                                                    │
# │ https://sf.eater.com/maps/best-coffee-shops-san-francisco                                                       │
# │ [7] The 10 Best Coffee Shops in San Francisco - The Friendly Traveler.                                          │
# │ https://thefriendlytraveler.com/san-francisco-coffee-shops/                                                     │
# │ [8] TOP 10 BEST Coffee Houses in San Francisco, CA - Yelp.                                                      │
# │ https://www.yelp.com/search?find_desc=Coffee+Houses&find_loc=San+Francisco%2C+CA                                │
# │ [9] TOP 10 BEST Scenic Coffee Shops in San Francisco, CA - Yelp.                                                │
# │ https://www.yelp.com/search?find_desc=Scenic+Coffee+Shops&find_loc=San+Francisco%2C+CA                          │
# │ [10] The Best Coffee Shops In SF - San Francisco - The Infatuation.                                             │
# │ https://www.theinfatuation.com/san-francisco/guides/best-coffee-shops-san-francisco                             │
# │ [11] 16 Best Coffee Shops In San Francisco - Tasting Table.                                                     │
# │ https://www.tastingtable.com/1479970/best-coffee-shops-san-francisco/                                           │
# │ [12] SCA Education. https://education.sca.coffee/                                                               │
# │ [13] SCA Skills Diploma | Recognize Your Coffee Expertise. https://education.sca.coffee/sca-skills-diploma      │
# │ [14] How SCA Coffee Education Works | Learn & Grow<br/>. https://education.sca.coffee/learners-how-it-works     │
# │ [15] THE COFFEE MOVEMENT, San Francisco - 2025 Reviews & Info.                                                  │
# │ https://www.tripadvisor.ca/Restaurant_Review-g60713-d16818989-Reviews-or15-The_Coffee_Movement-San_Francisco_Ca │
# │ lifornia.html                                                                                                   │
# │ [16] THE COFFEE MOVEMENT - 518 Photos & 243 Reviews - Yelp.                                                     │
# │ https://www.yelp.com/biz/the-coffee-movement-san-francisco-4                                                    │
# │ [17] The Coffee Movement - Coffee shop in Mission, San Francisco.                                               │
# │ https://www.postcard.inc/places/the-coffee-movement-san-francisco--O8B-DrOBe4                                   │
# │ [18] SIGHTGLASS COFFEE, San Francisco - 270 7th St, SoMa.                                                       │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d3468708-Reviews-Sightglass_Coffee-San_Francisco_Californi │
# │ a.html                                                                                                          │
# │ [19] SAN FRANCISCO: Coffee Movement Review - LetsGetLexi.                                                       │
# │ https://www.letsgetlexi.com/coffee/2020/10/15/san-francisco-coffee-movement-review                              │
# │ [20] The Coffee Movement - Coffee shop in Mission, San Francisco.                                               │
# │ https://www.postcard.inc/places/the-coffee-movement-san-francisco--O8B-DrOBe4                                   │
# │ [21] Super Popular San Francisco Shop Coffee Movement Just Brought ...                                          │
# │ https://sf.eater.com/2025/4/25/24416765/san-francisco-coffee-movement-side-a-opening-mission                    │
# │ [22] Sightglass Coffee - Yelp. https://www.yelp.com/biz/sightglass-coffee-san-francisco-15                      │
# │ [23] Sightglass - San Francisco (US) - The Coffeevine.                                                          │
# │ https://thecoffeevine.com/reviews/cafes/usa/san-francisco/sightglass-san-francisco-us/                          │
# │ [24] SIGHTGLASS COFFEE, San Francisco - 3014 20th St, Mission District.                                         │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d6398348-Reviews-Sightglass_Coffee-San_Francisco_Californi │
# │ a.html                                                                                                          │
# │ [25] SCA Education. https://education.sca.coffee/                                                               │
# │ [26] Sightglass Coffee.                                                                                         │
# │ https://sightglasscoffee.com/?srsltid=AfmBOorQQz9SSVTEtUZ4R0Fg_HTjppeel4BPQZ6A61f2lMoCSNMqtJwQ                  │
# │ [27] Classes - Sightglass Coffee.                                                                               │
# │ https://sightglasscoffee.com/pages/classes?srsltid=AfmBOorCDcggcZl4zlOxAAJFiNfkNjMXuf8kGiYHkTcuD_gVIjr7HH0s     │
# │ [28] Ritual Coffee Roasters - San Francisco Restaurants - Tripadvisor.                                          │
# │ https://www.tripadvisor.com/Restaurant_Review-g60713-d7227010-Reviews-Ritual_Coffee_Roasters-San_Francisco_Cali │
# │ fornia.html                                                                                                     │
# │ [29] Review: Ritual Coffee Roasters - Condé Nast Traveler.                                                      │
# │ https://www.cntraveler.com/restaurants/san-francisco/ritual-coffee-roasters                                     │
# │ [30] Ritual Academy - Ritual Coffee Co. https://ritual.coffee/collections/coffee-education                      │
# │ [31] SAN FRANCISCO: Saint Frank Coffee Review - LetsGetLexi.                                                    │
# │ https://www.letsgetlexi.com/coffee/2020/10/22/san-francisco-saint-frank-coffee-review                           │
# │ [32] Saint Frank Coffee - San Francisco. https://www.saintfrankcoffee.com/                                      │
# │ [33] Andytown Coffee Roasters --. https://www.bestcoffee.guide/pages/cafe-andytown-coffee-roasters-us-4521      │
# │ [34] Andytown Coffee Roasters | San Francisco Specialty Coffee.                                                 │
# │ https://andytownsf.com/?srsltid=AfmBOootI7D8Ti16qAjUuynY2d1tohWe7L0tS2CERkJ5nFdkDgZYhkvV                        │
# │ [35] WHOLESALE - Andytown Coffee Roasters.                                                                      │
# │ https://andytownsf.com/pages/wholesale-coffee?srsltid=AfmBOoqB248IToaSFWFgWI-f6lX9PqtZFtjDtdlNy7Yi1pBZX8ZhBp48  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ 🔧 Tool Call: ResearchComplete                                                                                  │
# │    Args: {}                                                                                                     │
# │    ID: 5ede0711-70b2-43e9-b12b-763d9fd84bd7                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# We can look at the trace [here](https://smith.langchain.com/public/99eaaecd-fd9a-4ead-8eed-abdfe4ab9288/r).
#
# ### LangGraph Studio
#
# Just as we did before, we can also use LangGraph Studio to visualize the agent.
#
# This agent has been added to the `langgraph.json` file, so you can select `research_agent_supervisor` in the dropdown menu:
#
# ```
# "research_agent_supervisor": "./src/deep_research_from_scratch/multi_agent_supervisor.py:supervisor_agent",
# ```
#
# Run the following command to start the studio
#
# ```bash
# uvx --refresh --from "langgraph-cli[inmem]" --with-editable . --python 3.11 langgraph dev --allow-blocking
# ```
#
# ## Eval
#
# The clear benefit of multi-agent is context isolation when there are clearly separable sub-topics. As we discuss [in our blog](https://blog.langchain.com/open-deep-research/):
#
# > Our experiments showed that single agent response quality suffers if the request has multiple sub-topics (e.g., compare A to B to C). The intuition here is straightforward: a single context window needs to store and reason about tool feedback across all of the sub-topics. This tool feedback is often token heavy. Numerous failure modes, such as context clash, become prevalent as the context window accumulates tool calls across many different sub-topics.
#
# But, we want to be careful not to spawn sub-agents in cases where it is not required:
#
# > The supervisor can handle both cases by selectively spawning sub-agents to tune the level of research depth needed for a request. The supervisor is prompted with heuristics to reason about when research should be parallelized, and when a single thread of research is sufficient. Our deep research agent has the flexibility to choose whether to parallelize research or not.
#
# Let's set up a few tests to make sure that we are parallelizing when it makes sense.

# %%
# Example messages with think_tool calls and tool messages for evaluation
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage

should_parallelize = [
    HumanMessage(content="Compare OpenAI vs Gemini deep research."),
    AIMessage(content="I need to analyze this request to determine if can should be parallelized.", tool_calls=[
        {
            "name": "think_tool",
            "args": {"reflection": "This is a comparison task involving two distinct AI products: OpenAI v Gemini Deep Research."},
            "id": "call_think_1"
        }
    ]),
    ToolMessage(content="Analysis complete: This is a comparison task involving two distinct AI products: OpenAI v Gemini Deep Research.", tool_call_id="call_think_1", name="think_tool")
]

should_not_parallelize = [
    HumanMessage(content="What are the top three Chinese restaurants in Chelsea, Manhattan"),
    AIMessage(content="Let me think about whether this task requires parallelization.", tool_calls=[
        {
            "name": "think_tool", 
            "args": {"reflection": "This is a ranking/listing task for restaurants in a specific geographic area (Chelsea, Manhattan)."},
            "id": "call_think_2"
        }
    ]),
    ToolMessage(content="Analysis complete: This is a ranking/listing task for restaurants in a specific geographic area (Chelsea, Manhattan).", tool_call_id="call_think_2", name="think_tool")
]

# %%
import os
from langsmith import Client

# Initialize client 
langsmith_client = Client(api_key=os.getenv("LANGSMITH_API_KEY"))

# Create the dataset
dataset_name = "deep_research_supervisor_parallelism"
if not langsmith_client.has_dataset(dataset_name=dataset_name):

    dataset = langsmith_client.create_dataset(
        dataset_name=dataset_name,
        description="A dataset that evaluates whether a supervisor can accurately decide when to parallelize research.",
    )

    langsmith_client.create_examples(
        dataset_id=dataset.id,
        examples=[
            {
                "inputs": {"supervisor_messages": should_parallelize},
                "outputs": {"num_expected_threads": 2},
            },
            {
                "inputs": {"supervisor_messages": should_not_parallelize},
                "outputs": {"num_expected_threads": 1},
            },
        ],
    )

# %% [markdown]
# Now we can run evals.

# %%
import uuid

def evaluate_parallelism(outputs: dict, reference_outputs:dict):
    tool_calls = outputs["output"].update["supervisor_messages"][-1].tool_calls
    return {
        "key": "correct_next_step",
        "score": len(tool_calls) == reference_outputs["num_expected_threads"]
    }

async def target_func(inputs: dict):
    config = {"configurable": {"thread_id": uuid.uuid4()}}
    return await supervisor_agent.nodes["supervisor"].ainvoke(inputs, config=config)

await langsmith_client.aevaluate(
    target_func,
    data=dataset_name,
    evaluators=[evaluate_parallelism],
    experiment_prefix="Supervisor Parallelism",
)
# Out:
# I0000 00:00:1761830437.751880  906049 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1761830439.163433  906049 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# View the evaluation results for experiment: 'Supervisor Parallelism-8dab609f' at:
# https://smith.langchain.com/o/b3ab263e-90f6-44bb-8602-7305d2542c40/datasets/977bdf25-225a-48f4-8c5b-d42551ace9e0/compare?selectedSessions=0bbdd903-2783-48b7-8c92-f81af38f3cf1
# I0000 00:00:1761830440.224316  906049 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# 0it [00:00, ?it/s]
# <AsyncExperimentResults Supervisor Parallelism-8dab609f>

# %% [markdown]
# In the first example, we asked the agent to compare and contrast products.
#
# This sort of problem is great for parallel research, and we expect the agent to deep dive into each lab in parallel before synthesizing findings when writing the report.
#
# The second example asks the agent for the top restaurants in Chelsea, Manhattan.
#
# The agent needs to conduct a single thread of research here and reflect on websites that presumably list out highly rated restaurants.
#
# There's not an obvious opportunity for parallelism for this ranking task.
